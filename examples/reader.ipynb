# %%
from discoket.reader import (Reader,
                             box_stairs_reader,
                             box_stairs_with_discard_reader,
                             cups_reader,
                             spiders_reader)

# %%
sentence = 'This is a sentence'

# %%
try:
    Reader()
except TypeError as e:
    print(e)
# Out:
# This class cannot be directly instantiated since neither `sentence2diagram` and `sentences2diagrams` have been implemented. See `help(Reader)` for more details.

# %%
box_stairs_reader.sentence2diagram(sentence).draw()

# %%
box_stairs_with_discard_reader.sentence2diagram(sentence).draw()

# %%
cups_reader.sentence2diagram(sentence).draw()

# %%
spiders_reader.sentence2diagram(sentence).draw()
